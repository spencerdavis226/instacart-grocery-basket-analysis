# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables.ipynb — TOC
# 	1.	Setup (imports + paths)
# 	2.	Exercise
#         2.1 Create + check dataframe
#         2.2 Grouping with pandas
#         2.3 Aggregating with agg()
#         2.4 Aggregating with transform()
#         2.5 Deriving columns with loc()
# 	3.	Task
#         3.1 Run aggregations on full dataset
#         3.2 Investigate price outliers
#         3.3 Decision / handling for outliers (flag/exclude)
# 	4.	Outputs / notes

# %% [markdown]
# # Importing

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import datasets
path = r'/Users/spencer/Documents/Career Foundry/Data Immersion/4 Python Fundamentals for Data Analysts/Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Create and check dataframe

# %%
# Create subset of first 1M
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda      77.0
# 1          0  Organic Unsweetened Vanilla Almond Milk      91.0
# 2          0                      Original Beef Jerky      23.0
# 3          0               Aged White Cheddar Popcorn      23.0
# 4          0         XL Pick-A-Size Paper Towel Rolls      54.0
#
#    department_id  prices        price_label     busiest_day    busiest_days  \
# 0            7.0     9.0  Mid-range product  Regularly busy  Regularly busy
# 1           16.0    12.5  Mid-range product  Regularly busy  Regularly busy
# 2           19.0     4.4  Low-range product  Regularly busy  Regularly busy
# 3           19.0     4.7  Low-range product  Regularly busy  Regularly busy
# 4           17.0     1.0  Low-range product  Regularly busy  Regularly busy
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2        Average orders
# 3        Average orders
# 4        Average orders

# %% [markdown]
# ## Grouping Data with pandas

# %% [markdown]
# You should always use the groupby() function as part of a series of steps, namely, the following:
#
# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# %% [markdown]
# ### Split data into groups

# %%
df.groupby('product_name')

# %% [markdown]
# ### Aggregating Data with agg()

# %% [markdown]
# #### Performing a Single Aggregation

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.793523
# 2.0              17.091743
# 3.0              17.920595
# 4.0              17.893164
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             15.617735
# 13.0             16.485052
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.015014
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630640
# 20.0             17.138204
# 21.0             21.996844

# %%
# Same result without agg() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.793523
# 2.0     17.091743
# 3.0     17.920595
# 4.0     17.893164
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.617735
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.015014
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630640
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %% [markdown]
# #### Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.793523   1  99
# 2.0              17.091743   1  98
# 3.0              17.920595   1  99
# 4.0              17.893164   1  99
# 5.0              15.214270   1  99
# 6.0              15.382228   1  99
# 7.0              17.699986   1  99
# 8.0              16.485269   1  91
# 9.0              15.965921   1  99
# 10.0             20.091818   1  99
# 11.0             16.485395   1  99
# 12.0             15.617735   1  99
# 13.0             16.485052   1  99
# 14.0             17.523474   1  99
# 15.0             15.690354   1  99
# 16.0             18.015014   1  99
# 17.0             16.155822   1  99
# 18.0             19.606536   1  99
# 19.0             17.630640   1  99
# 20.0             17.138204   1  99
# 21.0             21.996844   1  97

# %% [markdown]
# ### Aggregating Data with transform()

# %% [markdown]
# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
# All 3 steps in 1 code
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform("max")

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                      NaN         True       14084                  2
# 2                      NaN         True       12427                  3
# 3                      NaN         True       26088                  4
# 4                      NaN         True       26405                  5
# ..                     ...          ...         ...                ...
# 95                     8.0        False       21150                 13
# 96                     8.0        False       47144                  1
# 97                     8.0        False        5322                  2
# 98                     8.0        False       17224                  3
# 99                     8.0        False       38656                  4
#
#     reordered                                       product_name  aisle_id  \
# 0           0                                               Soda      77.0
# 1           0            Organic Unsweetened Vanilla Almond Milk      91.0
# 2           0                                Original Beef Jerky      23.0
# 3           0                         Aged White Cheddar Popcorn      23.0
# 4           0                   XL Pick-A-Size Paper Towel Rolls      54.0
# ..        ...                                                ...       ...
# 95          0                            Fire Grilled Steak Bowl      38.0
# 96          0     Unsweetened Original Almond Breeze Almond Milk      91.0
# 97          0  Gluten Free Dark Chocolate Chunk Chewy with a ...       3.0
# 98          0                   Oats & Honey Gluten Free Granola       3.0
# 99          0  Gluten Free Peanut Butter Dark Chocolate Chewy...       3.0
#
#     department_id  prices        price_label     busiest_day    busiest_days  \
# 0             7.0     9.0  Mid-range product  Regularly busy  Regularly busy
# 1            16.0    12.5  Mid-range product  Regularly busy  Regularly busy
# 2            19.0     4.4  Low-range product  Regularly busy  Regularly busy
# 3            19.0     4.7  Low-range product  Regularly busy  Regularly busy
# 4            17.0     1.0  Low-range product  Regularly busy  Regularly busy
# ..            ...     ...                ...             ...             ...
# 95            1.0     5.9  Mid-range product  Regularly busy  Regularly busy
# 96           16.0    14.0  Mid-range product  Regularly busy      Least busy
# 97           19.0     2.9  Low-range product  Regularly busy      Least busy
# 98           19.0     1.6  Low-range product  Regularly busy      Least busy
# 99           19.0     3.4  Low-range product  Regularly busy      Least busy
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# ..                   ...        ...
# 95           Most orders         14
# 96           Most orders         14
# 97           Most orders         14
# 98           Most orders         14
# 99           Most orders         14
#
# [100 rows x 19 columns]

# %% [markdown]
# ### Deriving Columns with loc()

# %%
# Create loyalty flags based on max orders
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check values
ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15891172
# Loyal customer      10293959
# New customer         6249358
# Name: count, dtype: int64

# %%
# Check head() of only columns of interest using df['column']
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# # Task

# %%
# Task 1 verification
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda      77.0
# 1          0  Organic Unsweetened Vanilla Almond Milk      91.0
# 2          0                      Original Beef Jerky      23.0
# 3          0               Aged White Cheddar Popcorn      23.0
# 4          0         XL Pick-A-Size Paper Towel Rolls      54.0
#
#    department_id  prices        price_label     busiest_day    busiest_days  \
# 0            7.0     9.0  Mid-range product  Regularly busy  Regularly busy
# 1           16.0    12.5  Mid-range product  Regularly busy  Regularly busy
# 2           19.0     4.4  Low-range product  Regularly busy  Regularly busy
# 3           19.0     4.7  Low-range product  Regularly busy  Regularly busy
# 4           17.0     1.0  Low-range product  Regularly busy  Regularly busy
#
#   busiest_period_of_day  max_order  loyalty_flag
# 0        Average orders         10  New customer
# 1        Average orders         10  New customer
# 2        Average orders         10  New customer
# 3        Average orders         10  New customer
# 4        Average orders         10  New customer

# %%
# 2. Create aggregated mean of “order_number” column grouped by “department_id”
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.457838
# 2.0     17.277920
# 3.0     17.170395
# 4.0     17.811403
# 5.0     15.215751
# 6.0     16.439806
# 7.0     17.225802
# 8.0     15.340650
# 9.0     15.895474
# 10.0    20.197148
# 11.0    16.170638
# 12.0    15.887671
# 13.0    16.583536
# 14.0    16.773669
# 15.0    16.165037
# 16.0    17.666284
# 17.0    15.694469
# 18.0    19.310514
# 19.0    17.177343
# 20.0    16.473447
# 21.0    22.902379
# Name: order_number, dtype: float64

# %%
# 3. Analyze the result
# Compare to subset results:
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.793523
# 2.0     17.091743
# 3.0     17.920595
# 4.0     17.893164
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.617735
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.015014
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630640
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %% [markdown]
# ## The aggregations results for the entire dataframe are similar to that of the subset. The departments with the highest mean order remains the same (dept 21).

# %%
# 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.
# Already completed:
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head()
# Out:
#    user_id  loyalty_flag  order_number
# 0        1  New customer             1
# 1        1  New customer             1
# 2        1  New customer             1
# 3        1  New customer             1
# 4        1  New customer             1

# %%
# 5.The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified.
ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal customer      10.386384
# New customer        13.294943
# Regular customer    12.495916
# Name: prices, dtype: float64

# %% [markdown]
# ## This seems a little high on average for a normal grocery store item. Checking some stats:

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.240429e+07
# mean     1.198038e+01
# std      4.956598e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# ## -> $99,999 is crazy high for a grocery store item. Doing some investigating

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16534      3264360      135             2                   2
# 16540       892534      135             3                   0
# 53711       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32350064   3172853   205650            18                   1
# 32377297   2504315   205818             3                   5
# 32377307   1108388   205818             5                   4
# 32410137   1916142   206049             1                   2
# 32410161    379732   206049             4                   1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 1576                     14                     5.0        False       21553
# 1638                     16                     4.0        False       21553
# 16534                    21                    13.0        False       21553
# 16540                     8                    12.0        False       21553
# 53711                    19                    30.0        False       21553
# ...                     ...                     ...          ...         ...
# 32350064                  9                     7.0        False       21553
# 32377297                 15                     3.0        False       21553
# 32377307                  5                     1.0        False       21553
# 32410137                 17                     NaN         True       21553
# 32410161                 14                     5.0        False       21553
#
#           add_to_cart_order  reordered                      product_name  \
# 1576                      5          0  Lowfat 2% Milkfat Cottage Cheese
# 1638                      3          1  Lowfat 2% Milkfat Cottage Cheese
# 16534                     6          0  Lowfat 2% Milkfat Cottage Cheese
# 16540                     3          1  Lowfat 2% Milkfat Cottage Cheese
# 53711                     9          0  Lowfat 2% Milkfat Cottage Cheese
# ...                     ...        ...                               ...
# 32350064                 17          1  Lowfat 2% Milkfat Cottage Cheese
# 32377297                 13          0  Lowfat 2% Milkfat Cottage Cheese
# 32377307                  5          1  Lowfat 2% Milkfat Cottage Cheese
# 32410137                  2          0  Lowfat 2% Milkfat Cottage Cheese
# 32410161                  4          1  Lowfat 2% Milkfat Cottage Cheese
#
#           aisle_id  department_id   prices         price_label  \
# 1576         108.0           16.0  14900.0  High-range product
# 1638         108.0           16.0  14900.0  High-range product
# 16534        108.0           16.0  14900.0  High-range product
# 16540        108.0           16.0  14900.0  High-range product
# 53711        108.0           16.0  14900.0  High-range product
# ...            ...            ...      ...                 ...
# 32350064     108.0           16.0  14900.0  High-range product
# 32377297     108.0           16.0  14900.0  High-range product
# 32377307     108.0           16.0  14900.0  High-range product
# 32410137     108.0           16.0  14900.0  High-range product
# 32410161     108.0           16.0  14900.0  High-range product
#
#              busiest_day    busiest_days busiest_period_of_day  max_order  \
# 1576      Regularly busy  Regularly busy           Most orders         40
# 1638      Regularly busy  Regularly busy           Most orders         40
# 16534     Regularly busy  Regularly busy        Average orders          4
# 16540        Busiest day    Busiest days        Average orders          4
# 53711     Regularly busy    Busiest days        Average orders         16
# ...                  ...             ...                   ...        ...
# 32350064  Regularly busy    Busiest days           Most orders         25
# 32377297  Regularly busy  Regularly busy           Most orders         25
# 32377307      Least busy      Least busy         Fewest orders         25
# 32410137  Regularly busy  Regularly busy        Average orders          5
# 32410161  Regularly busy    Busiest days           Most orders          5
#
#               loyalty_flag
# 1576      Regular customer
# 1638      Regular customer
# 16534         New customer
# 16540         New customer
# 53711     Regular customer
# ...                    ...
# 32350064  Regular customer
# 32377297  Regular customer
# 32377307  Regular customer
# 32410137      New customer
# 32410161      New customer
#
# [5127 rows x 20 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 90000]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 129036      183964      873             3                   0
# 129049     1851256      873             4                   6
# 284539     1915696     1893             1                   5
# 284550     2763293     1893             2                   4
# 284573     2564805     1893             4                   1
# ...            ...      ...           ...                 ...
# 32109300   2249946   204099            29                   0
# 32109317   2363282   204099            31                   0
# 32155162   3181945   204395            13                   3
# 32284597   2486215   205227             7                   3
# 32284651   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 129036                   10                     7.0        False       33664
# 129049                   12                    13.0        False       33664
# 284539                   17                     NaN         True       33664
# 284550                   16                    13.0        False       33664
# 284573                   17                    30.0        False       33664
# ...                     ...                     ...          ...         ...
# 32109300                  8                     4.0        False       33664
# 32109317                  9                     2.0        False       33664
# 32155162                 15                     8.0        False       33664
# 32284597                 20                     4.0        False       33664
# 32284651                 11                     4.0        False       33664
#
#           add_to_cart_order  reordered           product_name  aisle_id  \
# 129036                   11          0  2 % Reduced Fat  Milk      84.0
# 129049                    8          1  2 % Reduced Fat  Milk      84.0
# 284539                   10          0  2 % Reduced Fat  Milk      84.0
# 284550                    6          1  2 % Reduced Fat  Milk      84.0
# 284573                    3          1  2 % Reduced Fat  Milk      84.0
# ...                     ...        ...                    ...       ...
# 32109300                  1          0  2 % Reduced Fat  Milk      84.0
# 32109317                  1          1  2 % Reduced Fat  Milk      84.0
# 32155162                 25          0  2 % Reduced Fat  Milk      84.0
# 32284597                  8          0  2 % Reduced Fat  Milk      84.0
# 32284651                 23          1  2 % Reduced Fat  Milk      84.0
#
#           department_id   prices         price_label     busiest_day  \
# 129036             16.0  99999.0  High-range product     Busiest day
# 129049             16.0  99999.0  High-range product  Regularly busy
# 284539             16.0  99999.0  High-range product  Regularly busy
# 284550             16.0  99999.0  High-range product      Least busy
# 284573             16.0  99999.0  High-range product  Regularly busy
# ...                 ...      ...                 ...             ...
# 32109300           16.0  99999.0  High-range product     Busiest day
# 32109317           16.0  99999.0  High-range product     Busiest day
# 32155162           16.0  99999.0  High-range product  Regularly busy
# 32284597           16.0  99999.0  High-range product  Regularly busy
# 32284651           16.0  99999.0  High-range product     Busiest day
#
#             busiest_days busiest_period_of_day  max_order      loyalty_flag
# 129036      Busiest days           Most orders          8      New customer
# 129049    Regularly busy           Most orders          8      New customer
# 284539    Regularly busy        Average orders          6      New customer
# 284550        Least busy           Most orders          6      New customer
# 284573      Busiest days        Average orders          6      New customer
# ...                  ...                   ...        ...               ...
# 32109300    Busiest days        Average orders         39  Regular customer
# 32109317    Busiest days           Most orders         39  Regular customer
# 32155162      Least busy           Most orders         15  Regular customer
# 32284597      Least busy        Average orders         12  Regular customer
# 32284651    Busiest days           Most orders         12  Regular customer
#
# [698 rows x 20 columns]

# %% [markdown]
# ## This is either free-range cottage cheese and milk imported from space, or there's a pricing error. Assume pricing error

# %%
# Turn values > 100 into NaNs
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %%
# Check for outliers again
ords_prods_merge.loc[ords_prods_merge['prices'] > 50]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, price_label, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag]
# Index: []

# %%
# Complete task 5 again with cleaned data
ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal customer      7.773606
# New customer        7.801332
# Regular customer    7.798362
# Name: prices, dtype: float64

# %%
# 6. Create a spending flag for each user based on the average price across all their orders
ords_prods_merge['user_avg_item_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform("mean")

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                      NaN         True       14084                  2
# 2                      NaN         True       12427                  3
# 3                      NaN         True       26088                  4
# 4                      NaN         True       26405                  5
# ..                     ...          ...         ...                ...
# 95                     8.0        False       21150                 13
# 96                     8.0        False       47144                  1
# 97                     8.0        False        5322                  2
# 98                     8.0        False       17224                  3
# 99                     8.0        False       38656                  4
#
#     reordered  ... aisle_id  department_id  prices        price_label  \
# 0           0  ...     77.0            7.0     9.0  Mid-range product
# 1           0  ...     91.0           16.0    12.5  Mid-range product
# 2           0  ...     23.0           19.0     4.4  Low-range product
# 3           0  ...     23.0           19.0     4.7  Low-range product
# 4           0  ...     54.0           17.0     1.0  Low-range product
# ..        ...  ...      ...            ...     ...                ...
# 95          0  ...     38.0            1.0     5.9  Mid-range product
# 96          0  ...     91.0           16.0    14.0  Mid-range product
# 97          0  ...      3.0           19.0     2.9  Low-range product
# 98          0  ...      3.0           19.0     1.6  Low-range product
# 99          0  ...      3.0           19.0     3.4  Low-range product
#
#        busiest_day    busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy  Regularly busy        Average orders        10
# 1   Regularly busy  Regularly busy        Average orders        10
# 2   Regularly busy  Regularly busy        Average orders        10
# 3   Regularly busy  Regularly busy        Average orders        10
# 4   Regularly busy  Regularly busy        Average orders        10
# ..             ...             ...                   ...       ...
# 95  Regularly busy  Regularly busy           Most orders        14
# 96  Regularly busy      Least busy           Most orders        14
# 97  Regularly busy      Least busy           Most orders        14
# 98  Regularly busy      Least busy           Most orders        14
# 99  Regularly busy      Least busy           Most orders        14
#
#         loyalty_flag user_avg_item_price
# 0       New customer            6.367797
# 1       New customer            6.367797
# 2       New customer            6.367797
# 3       New customer            6.367797
# 4       New customer            6.367797
# ..               ...                 ...
# 95  Regular customer            7.515897
# 96  Regular customer            7.515897
# 97  Regular customer            7.515897
# 98  Regular customer            7.515897
# 99  Regular customer            7.515897
#
# [100 rows x 21 columns]

# %%
# Create spending flags based on avg order price
ords_prods_merge.loc[ords_prods_merge['user_avg_item_price'] < 10, 'spending_habit'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['user_avg_item_price'] >= 10, 'spending_habit'] = 'High spender'

# %%
# Check values
ords_prods_merge['spending_habit'].value_counts()
# Out:
# spending_habit
# Low spender     32314611
# High spender      119878
# Name: count, dtype: int64

# %%
# 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform("median")

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                      NaN         True       14084                  2
# 2                      NaN         True       12427                  3
# 3                      NaN         True       26088                  4
# 4                      NaN         True       26405                  5
# ..                     ...          ...         ...                ...
# 95                     8.0        False       21150                 13
# 96                     8.0        False       47144                  1
# 97                     8.0        False        5322                  2
# 98                     8.0        False       17224                  3
# 99                     8.0        False       38656                  4
#
#     reordered  ... prices        price_label     busiest_day    busiest_days  \
# 0           0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 1           0  ...   12.5  Mid-range product  Regularly busy  Regularly busy
# 2           0  ...    4.4  Low-range product  Regularly busy  Regularly busy
# 3           0  ...    4.7  Low-range product  Regularly busy  Regularly busy
# 4           0  ...    1.0  Low-range product  Regularly busy  Regularly busy
# ..        ...  ...    ...                ...             ...             ...
# 95          0  ...    5.9  Mid-range product  Regularly busy  Regularly busy
# 96          0  ...   14.0  Mid-range product  Regularly busy      Least busy
# 97          0  ...    2.9  Low-range product  Regularly busy      Least busy
# 98          0  ...    1.6  Low-range product  Regularly busy      Least busy
# 99          0  ...    3.4  Low-range product  Regularly busy      Least busy
#
#    busiest_period_of_day max_order      loyalty_flag user_avg_item_price  \
# 0         Average orders        10      New customer            6.367797
# 1         Average orders        10      New customer            6.367797
# 2         Average orders        10      New customer            6.367797
# 3         Average orders        10      New customer            6.367797
# 4         Average orders        10      New customer            6.367797
# ..                   ...       ...               ...                 ...
# 95           Most orders        14  Regular customer            7.515897
# 96           Most orders        14  Regular customer            7.515897
# 97           Most orders        14  Regular customer            7.515897
# 98           Most orders        14  Regular customer            7.515897
# 99           Most orders        14  Regular customer            7.515897
#
#     spending_habit median_days_between_orders
# 0      Low spender                       20.5
# 1      Low spender                       20.5
# 2      Low spender                       20.5
# 3      Low spender                       20.5
# 4      Low spender                       20.5
# ..             ...                        ...
# 95     Low spender                       13.0
# 96     Low spender                       13.0
# 97     Low spender                       13.0
# 98     Low spender                       13.0
# 99     Low spender                       13.0
#
# [100 rows x 23 columns]

# %%
# Create user frequency flags based on median days since prior order
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts()
# Out:
# order_frequency_flag
# Frequent customer        21577653
# Regular customer          7217190
# Non-frequent customer     3639646
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered  ...        price_label     busiest_day    busiest_days  \
# 0          0  ...  Mid-range product  Regularly busy  Regularly busy
# 1          0  ...  Mid-range product  Regularly busy  Regularly busy
# 2          0  ...  Low-range product  Regularly busy  Regularly busy
# 3          0  ...  Low-range product  Regularly busy  Regularly busy
# 4          0  ...  Low-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day max_order  loyalty_flag user_avg_item_price  \
# 0         Average orders        10  New customer            6.367797
# 1         Average orders        10  New customer            6.367797
# 2         Average orders        10  New customer            6.367797
# 3         Average orders        10  New customer            6.367797
# 4         Average orders        10  New customer            6.367797
#
#   spending_habit  median_days_between_orders   order_frequency_flag
# 0    Low spender                        20.5  Non-frequent customer
# 1    Low spender                        20.5  Non-frequent customer
# 2    Low spender                        20.5  Non-frequent customer
# 3    Low spender                        20.5  Non-frequent customer
# 4    Low spender                        20.5  Non-frequent customer
#
# [5 rows x 24 columns]

# %%
# 9. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
