# %% [markdown]
# # 4.2 Importing libraries and Python data types.ipynb — TOC
# 	1.	Setup (imports + environment)
# 	2.	Exercise: Importing libraries
# 	3.	Exercise: Python data types
#         3.1 Strings
#         3.2 Integers + floats
#         3.3 Lists + tuples
#         3.4 Dictionaries
#         3.5 Boolean logic / comparisons
# 	4.	Quick practice / checks
# 	5.	Notes / recap

# %% [markdown]
# # 01. Importing Data Types

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Data Types

# %% [markdown]
# ### Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables.

# %%
a = 40

# %%
b = 60

# %%
a + b
# Out:
# 100

# %%
c = 100

# %%
d = 0

# %%
c - d
# Out:
# 100

# %%
e = 50

# %%
f = 2

# %%
e * f
# Out:
# 100

# %% [markdown]
# ### Code 2 floating-point variables and divide them by each other.

# %%
g = 25.34732

# %%
h = 5.23826

# %%
g / h
# Out:
# 4.8388816133601615

# %% [markdown]
# ### Construct a short word made of separate strings (you’ll need to concatenate some strings!).

# %%
i = "He"

# %%
j = "llo"

# %%
i + j
# Out:
# 'Hello'

# %% [markdown]
# ### Construct 2 short sentences made of separate strings.

# %%
k = "Happy New Year! "

# %%
l = "Have a great January!"

# %%
k + l
# Out:
# 'Happy New Year! Have a great January!'

# %% [markdown]
# ### At the bottom of your file, include a command that makes a string appear 100 times.

# %%
k * 100
# Out:
# 'Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy New Year! Happy
# ...
